# %% [markdown]
# <a href="https://colab.research.google.com/github/TinizaraRodriguez/_easyOCR/blob/easyOCR_ordinales/_easyOCR_ordinales.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install easyocr
# !pip install imutils
# !pip install opencv-python
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.9/2.9 MB 10.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 908.3/908.3 kB 12.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 146.0/146.0 kB 6.2 MB/s eta 0:00:00
# ...

# %%
import os
import easyocr
import cv2
from matplotlib import pyplot as plt
import numpy as np
import re

# %%
IMAGE_PATH = '/content/MATRICULA.jpg'
reader = easyocr.Reader(['es'], gpu=False)
result = reader.readtext(IMAGE_PATH)
result
# Out:
# WARNING:easyocr.easyocr:Using CPU. Note: This module is much faster with a GPU.
# [([[71, 25], [2514, 25], [2514, 497], [71, 497]],
#   '7 G1-4-13-94',
#   0.2608918767020491),
#  ([[1022, 474], [1442, 474], [1442, 504], [1022, 504]],
#   'wwwfotocopiasbaratas.com',
#   0.695660244760406),
#  ([[1022, 506], [1362, 506], [1362, 538], [1022, 538]],
#   'MATERIAL DE OFICINA',
#   0.9280149293186317),
#  ([[1018, 542], [1042, 542], [1042, 570], [1018, 570]],
#   'E',
#   0.9859129342539887),
#  ([[1056, 542], [1218, 542], [1218, 572], [1056, 572]],
#   'IMPRENTA',
#   0.9906594051368259),
#  ([[1017, 573], [1453, 573], [1453, 609], [1017, 609]],
#   'DISTRIBUIDORES OFICIALES',
#   0.9224699259789233),
#  ([[1015, 607], [1405, 607], [1405, 648], [1015, 648]],
#   'Tlf y Wasapp 649 033 023',
#   0.8933300581259181),
#  ([[1015, 645], [1347, 645], [1347, 681], [1015, 681]],
#   'Envíos a Toda España',
#   0.8521005906246525)]

# %%
img = cv2.imread(IMAGE_PATH)
spacer = 100
for detection in result:
    top_left = tuple(detection[0][0])
    bottom_right = tuple(detection[0][2])
    text = detection[1]
    img = cv2.rectangle(img,top_left,bottom_right,(0,255,0),3)
    img = cv2.putText(img,text,(10,spacer), font, 1,(255,0,0),2,cv2.LINE_AA)
    spacer+=25
plt.figure(figsize=(10,10))
plt.imshow(img)
plt.show()

# %%
IMAGE_PATH = '/content/ejemplo.png'
reader = easyocr.Reader(['es'], gpu=False)
result = reader.readtext(IMAGE_PATH)
result
# Out:
# WARNING:easyocr.easyocr:Using CPU. Note: This module is much faster with a GPU.
# [([[18, 8], [206, 8], [206, 40], [18, 40]],
#   '6a BA-2-63-21',
#   0.9707551023921888),
#  ([[22, 92], [192, 92], [192, 118], [22, 118]],
#   '62 BA-2-63-21',
#   0.8111177874972476),
#  ([[18, 156], [212, 156], [212, 188], [18, 188]],
#   '6a BA-2-63-21',
#   0.9628515515303204),
#  ([[22, 240], [193, 240], [193, 268], [22, 268]],
#   '62-BA-2-63-21',
#   0.6706574383781239),
#  ([[24, 325], [213, 325], [213, 357], [24, 357]],
#   '62-BA-2-63-21',
#   0.318187058509366),
#  ([[24, 408], [193, 408], [193, 436], [24, 436]],
#   '69 BA-2-62-21',
#   0.7425419482168722),
#  ([[26, 484], [200, 484], [200, 510], [26, 510]],
#   '69-BA-2-63-21',
#   0.9565245344014626)]

# %%
img = cv2.imread(IMAGE_PATH)
spacer = 70
for detection in result:
    top_left = tuple(detection[0][0])
    bottom_right = tuple(detection[0][2])
    text = detection[1]
    img = cv2.rectangle(img,top_left,bottom_right,(0,255,0),3)
    img = cv2.putText(img,text,(10,spacer), font, 0.8,(255,0,0),2,cv2.LINE_AA)
    spacer+=80
plt.figure(figsize=(10,10))
plt.imshow(img)
plt.show()
